# %%
import numpy as np
import seaborn as sns

# %%
filepath = './results_fe/Xhat_centeredmean_50hz.npy'
Xhat_centeredmean_loaded = np.load(filepath, allow_pickle=True)

# %%
import matplotlib.pyplot as plt

plt.imshow(Xhat_centeredmean_loaded[0], aspect='auto')
plt.colorbar()
# Set the X-axis tick locations and labels
step = int(resample_frequency/2)  # Display every x labels
plt.xticks(range(0, len(time_labels), step), time_labels[::step])
plt.xlabel('Time (seconds)')
plt.ylabel('Centered Orientation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 plt.colorbar()
#       5 # Set the X-axis tick locations and labels
# ----> 6 step = int(resample_frequency/2)  # Display every x labels
#       7 plt.xticks(range(0, len(time_labels), step), time_labels[::step])
#       8 plt.xlabel('Time (seconds)')
#
# NameError: name 'resample_frequency' is not defined
